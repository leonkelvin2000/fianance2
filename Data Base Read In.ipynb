# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
#import tensorflow as tf

# %%
project_df = pd.read_csv("resources/salary.csv")
project_df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  salary
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %%
project_df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# salary            object
# dtype: object

# %%
project_df.sample(20)
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 6570    28   Self-emp-not-inc  123983   Some-college             10
# 31227   51   Self-emp-not-inc   95435        HS-grad              9
# 5825    49   Self-emp-not-inc   59612           10th              6
# 26700   26   Self-emp-not-inc  102476        HS-grad              9
# 21969   40        Federal-gov  544792   Some-college             10
# 23343   36       Self-emp-inc  306156   Some-college             10
# 5049    32            Private  473133        Masters             14
# 12776   39            Private  181943      Bachelors             13
# 16537   42            Private  159911        HS-grad              9
# 10201   21            Private  231053        HS-grad              9
# 28186   35   Self-emp-not-inc  238802        HS-grad              9
# 5423    33          State-gov  913447   Some-college             10
# 22602   51            Private  194259      Bachelors             13
# 21928   42            Private  194537        HS-grad              9
# 19528   28            Private  173110        HS-grad              9
# 803     31            Private   51471        HS-grad              9
# 2789    44       Self-emp-inc  133060   Some-college             10
# 29232   24            Private  200593        HS-grad              9
# 22449   37            Private  202950        HS-grad              9
# 24832   26            Private  331861      Bachelors             13
#
#             marital-status          occupation    relationship  \
# 6570    Married-civ-spouse               Sales       Own-child
# 31227   Married-civ-spouse               Sales         Husband
# 5825              Divorced     Farming-fishing       Unmarried
# 26700        Never-married        Craft-repair       Own-child
# 21969   Married-civ-spouse     Farming-fishing         Husband
# 23343   Married-civ-spouse               Sales         Husband
# 5049    Married-civ-spouse      Prof-specialty         Husband
# 12776        Never-married     Exec-managerial   Not-in-family
# 16537             Divorced       Other-service       Unmarried
# 10201        Never-married   Machine-op-inspct       Own-child
# 28186   Married-civ-spouse     Farming-fishing         Husband
# 5423              Divorced       Other-service       Unmarried
# 22602             Divorced        Tech-support       Unmarried
# 21928             Divorced   Machine-op-inspct       Unmarried
# 19528        Never-married     Exec-managerial   Not-in-family
# 803               Divorced        Adm-clerical       Unmarried
# 2789              Divorced   Machine-op-inspct   Not-in-family
# 29232   Married-civ-spouse   Handlers-cleaners         Husband
# 22449   Married-civ-spouse    Transport-moving         Husband
# 24832        Never-married     Exec-managerial   Not-in-family
#
#                       race      sex  capital-gain  capital-loss  \
# 6570    Asian-Pac-Islander     Male             0             0
# 31227                White     Male             0             0
# 5825                 White     Male             0             0
# 26700                White     Male             0             0
# 21969                White     Male             0             0
# 23343                White     Male         15024             0
# 5049                 White     Male             0             0
# 12776                White   Female             0             0
# 16537                White   Female             0             0
# 10201                White     Male             0             0
# 28186                White     Male             0             0
# 5423                 Black   Female             0             0
# 22602                White   Female             0             0
# 21928                White   Female             0             0
# 19528                White   Female             0             0
# 803                  White   Female             0             0
# 2789                 White     Male             0             0
# 29232                White     Male             0             0
# 22449                White     Male             0             0
# 24832                White     Male             0             0
#
#        hours-per-week  native-country  salary
# 6570               63           South   <=50K
# 31227              60   United-States    >50K
# 5825               70   United-States   <=50K
# 26700              50   United-States   <=50K
# 21969              40   United-States   <=50K
# 23343              60   United-States    >50K
# 5049               40   United-States    >50K
# 12776              35   United-States   <=50K
# 16537              40   United-States   <=50K
# 10201              30   United-States   <=50K
# 28186              50   United-States   <=50K
# 5423               40   United-States   <=50K
# 22602              40   United-States   <=50K
# 21928              40   United-States   <=50K
# 19528              40   United-States   <=50K
# 803                38   United-States   <=50K
# 2789               60   United-States   <=50K
# 29232              50   United-States   <=50K
# 22449              40   United-States    >50K
# 24832              60               ?   <=50K

# %%
project_df.nunique()
# Out:
# age                  73
# workclass             9
# fnlwgt            21648
# education            16
# education-num        16
# marital-status        7
# occupation           15
# relationship          6
# race                  5
# sex                   2
# capital-gain        119
# capital-loss         92
# hours-per-week       94
# native-country       42
# salary                2
# dtype: int64

# %%
## Create Features DataFrame
features_df = project_df.filter(['age', 'workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex','hours-per-week', 'native-country' ], axis = 1)
features_df
# Out:
#        age          workclass    education       marital-status  \
# 0       39          State-gov    Bachelors        Never-married
# 1       50   Self-emp-not-inc    Bachelors   Married-civ-spouse
# 2       38            Private      HS-grad             Divorced
# 3       53            Private         11th   Married-civ-spouse
# 4       28            Private    Bachelors   Married-civ-spouse
# ...    ...                ...          ...                  ...
# 32556   27            Private   Assoc-acdm   Married-civ-spouse
# 32557   40            Private      HS-grad   Married-civ-spouse
# 32558   58            Private      HS-grad              Widowed
# 32559   22            Private      HS-grad        Never-married
# 32560   52       Self-emp-inc      HS-grad   Married-civ-spouse
#
#                occupation    relationship    race      sex  hours-per-week  \
# 0            Adm-clerical   Not-in-family   White     Male              40
# 1         Exec-managerial         Husband   White     Male              13
# 2       Handlers-cleaners   Not-in-family   White     Male              40
# 3       Handlers-cleaners         Husband   Black     Male              40
# 4          Prof-specialty            Wife   Black   Female              40
# ...                   ...             ...     ...      ...             ...
# 32556        Tech-support            Wife   White   Female              38
# 32557   Machine-op-inspct         Husband   White     Male              40
# 32558        Adm-clerical       Unmarried   White   Female              40
# 32559        Adm-clerical       Own-child   White     Male              20
# 32560     Exec-managerial            Wife   White   Female              40
#
#        native-country
# 0       United-States
# 1       United-States
# 2       United-States
# 3       United-States
# 4                Cuba
# ...               ...
# 32556   United-States
# 32557   United-States
# 32558   United-States
# 32559   United-States
# 32560   United-States
#
# [32561 rows x 10 columns]

# %%
#create target df
target_df = project_df.filter(['age','salary'], axis=1)
target_df
# Out:
#        age  salary
# 0       39   <=50K
# 1       50   <=50K
# 2       38   <=50K
# 3       53   <=50K
# 4       28   <=50K
# ...    ...     ...
# 32556   27   <=50K
# 32557   40    >50K
# 32558   58   <=50K
# 32559   22   <=50K
# 32560   52    >50K
#
# [32561 rows x 2 columns]

# %%
# Renaming titles columns
features_df = features_df.rename(columns={'workclass':'work_class','marital-status': 'martial_status','hours-per-week':'hours_per_week','native-country':'native_country'})
features_df
# Out:
#        age         work_class    education       martial_status  \
# 0       39          State-gov    Bachelors        Never-married
# 1       50   Self-emp-not-inc    Bachelors   Married-civ-spouse
# 2       38            Private      HS-grad             Divorced
# 3       53            Private         11th   Married-civ-spouse
# 4       28            Private    Bachelors   Married-civ-spouse
# ...    ...                ...          ...                  ...
# 32556   27            Private   Assoc-acdm   Married-civ-spouse
# 32557   40            Private      HS-grad   Married-civ-spouse
# 32558   58            Private      HS-grad              Widowed
# 32559   22            Private      HS-grad        Never-married
# 32560   52       Self-emp-inc      HS-grad   Married-civ-spouse
#
#                occupation    relationship    race      sex  hours_per_week  \
# 0            Adm-clerical   Not-in-family   White     Male              40
# 1         Exec-managerial         Husband   White     Male              13
# 2       Handlers-cleaners   Not-in-family   White     Male              40
# 3       Handlers-cleaners         Husband   Black     Male              40
# 4          Prof-specialty            Wife   Black   Female              40
# ...                   ...             ...     ...      ...             ...
# 32556        Tech-support            Wife   White   Female              38
# 32557   Machine-op-inspct         Husband   White     Male              40
# 32558        Adm-clerical       Unmarried   White   Female              40
# 32559        Adm-clerical       Own-child   White     Male              20
# 32560     Exec-managerial            Wife   White   Female              40
#
#        native_country
# 0       United-States
# 1       United-States
# 2       United-States
# 3       United-States
# 4                Cuba
# ...               ...
# 32556   United-States
# 32557   United-States
# 32558   United-States
# 32559   United-States
# 32560   United-States
#
# [32561 rows x 10 columns]

# %%
# Add this import for sql database
import sqlite3

# %%
# connecting to 'features.db'
conn = sqlite3.connect('Salary.db')

# %%
# Adding feature_df database
features_df.to_sql(name ='features', con=conn, if_exists='replace', index=False)
conn.commit
# Out:
# <function Connection.commit>

# %%
# Adding target_df to database
target_df.to_sql(name ='target', con=conn, if_exists='replace', index=False)
conn.commit
# Out:
# <function Connection.commit>

# %%
# connecting to 'target.db'
conn = sqlite3.connect('salary.db')
