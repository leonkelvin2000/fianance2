# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf

# %%
project_df = pd.read_csv("resources\salary.csv")
project_df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  salary
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %%
project_df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# salary            object
# dtype: object

# %%
project_df.sample(20)
# Out:
#        age      workclass  fnlwgt      education  education-num  \
# 15832   60      State-gov  234854      Doctorate             16
# 8986    20        Private   50397   Some-college             10
# 23732   32        Private   70985      Assoc-voc             11
# 32112   32   Self-emp-inc  209691      Bachelors             13
# 9092    21        Private  294295        HS-grad              9
# 14238   72   Self-emp-inc  172407    Prof-school             15
# 7979    48        Private   47343        Masters             14
# 14432   21        Private  275395   Some-college             10
# 18233   45        Private  129387     Assoc-acdm             12
# 21007   61        Private  101265   Some-college             10
# 6418    20        Private  115824           11th              7
# 31843   67      Local-gov  204123      Bachelors             13
# 19341   40        Private  360884   Some-college             10
# 14860   72              ?  237229      Assoc-voc             11
# 18684   59   Self-emp-inc  169982   Some-college             10
# 6862    51              ?   69328      Assoc-voc             11
# 698     30        Private  189620      Bachelors             13
# 6129    63        Private   88653   Some-college             10
# 32104   26        Private  385278        HS-grad              9
# 31978   41        Private   29762        HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 15832   Married-civ-spouse      Prof-specialty         Husband   White
# 8986    Married-civ-spouse               Sales         Husband   Black
# 23732   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32112   Married-civ-spouse        Craft-repair         Husband   White
# 9092         Never-married        Adm-clerical       Unmarried   White
# 14238   Married-civ-spouse      Prof-specialty         Husband   White
# 7979    Married-civ-spouse      Prof-specialty         Husband   White
# 14432        Never-married        Craft-repair       Own-child   White
# 18233             Divorced        Tech-support       Unmarried   White
# 21007             Divorced        Adm-clerical       Unmarried   White
# 6418    Married-civ-spouse   Handlers-cleaners         Husband   White
# 31843   Married-civ-spouse      Prof-specialty         Husband   White
# 19341   Married-civ-spouse        Adm-clerical            Wife   White
# 14860              Widowed                   ?   Not-in-family   White
# 18684   Married-civ-spouse     Exec-managerial         Husband   White
# 6862    Married-civ-spouse                   ?         Husband   White
# 698          Never-married      Prof-specialty       Own-child   White
# 6129    Married-civ-spouse      Prof-specialty         Husband   White
# 32104   Married-civ-spouse     Exec-managerial         Husband   Black
# 31978   Married-civ-spouse        Craft-repair         Husband   White
#
#            sex  capital-gain  capital-loss  hours-per-week  native-country  \
# 15832     Male             0          1902              40   United-States
# 8986      Male             0             0              35   United-States
# 23732     Male             0             0              40   United-States
# 32112     Male             0             0              50          Canada
# 9092      Male             0             0              40   United-States
# 14238     Male         99999             0              50   United-States
# 7979      Male             0             0              40   United-States
# 14432     Male             0             0              40   United-States
# 18233   Female             0             0              40               ?
# 21007   Female             0             0              43   United-States
# 6418      Male             0          1573              40   United-States
# 31843     Male             0             0              10   United-States
# 19341   Female          7298             0              40   United-States
# 14860   Female             0             0              30   United-States
# 18684     Male         15024             0              60   United-States
# 6862      Male             0             0              50   United-States
# 698     Female             0             0              40          Poland
# 6129      Male             0             0              40               ?
# 32104     Male             0             0              60   United-States
# 31978     Male             0             0              52   United-States
#
#        salary
# 15832    >50K
# 8986    <=50K
# 23732   <=50K
# 32112   <=50K
# 9092    <=50K
# 14238    >50K
# 7979     >50K
# 14432   <=50K
# 18233   <=50K
# 21007   <=50K
# 6418    <=50K
# 31843   <=50K
# 19341    >50K
# 14860   <=50K
# 18684    >50K
# 6862     >50K
# 698     <=50K
# 6129    <=50K
# 32104   <=50K
# 31978    >50K

# %%
project_df.nunique()
# Out:
# age                  73
# workclass             9
# fnlwgt            21648
# education            16
# education-num        16
# marital-status        7
# occupation           15
# relationship          6
# race                  5
# sex                   2
# capital-gain        119
# capital-loss         92
# hours-per-week       94
# native-country       42
# salary                2
# dtype: int64

# %%
## Create Features DataFrame
features_df = project_df.filter(['age', 'workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex','hours-per-week', 'native-country' ], axis = 1)
features_df
# Out:
#        age          workclass    education       marital-status  \
# 0       39          State-gov    Bachelors        Never-married
# 1       50   Self-emp-not-inc    Bachelors   Married-civ-spouse
# 2       38            Private      HS-grad             Divorced
# 3       53            Private         11th   Married-civ-spouse
# 4       28            Private    Bachelors   Married-civ-spouse
# ...    ...                ...          ...                  ...
# 32556   27            Private   Assoc-acdm   Married-civ-spouse
# 32557   40            Private      HS-grad   Married-civ-spouse
# 32558   58            Private      HS-grad              Widowed
# 32559   22            Private      HS-grad        Never-married
# 32560   52       Self-emp-inc      HS-grad   Married-civ-spouse
#
#                occupation    relationship    race      sex  hours-per-week  \
# 0            Adm-clerical   Not-in-family   White     Male              40
# 1         Exec-managerial         Husband   White     Male              13
# 2       Handlers-cleaners   Not-in-family   White     Male              40
# 3       Handlers-cleaners         Husband   Black     Male              40
# 4          Prof-specialty            Wife   Black   Female              40
# ...                   ...             ...     ...      ...             ...
# 32556        Tech-support            Wife   White   Female              38
# 32557   Machine-op-inspct         Husband   White     Male              40
# 32558        Adm-clerical       Unmarried   White   Female              40
# 32559        Adm-clerical       Own-child   White     Male              20
# 32560     Exec-managerial            Wife   White   Female              40
#
#        native-country
# 0       United-States
# 1       United-States
# 2       United-States
# 3       United-States
# 4                Cuba
# ...               ...
# 32556   United-States
# 32557   United-States
# 32558   United-States
# 32559   United-States
# 32560   United-States
#
# [32561 rows x 10 columns]

# %%
#create target df
target_df = project_df.filter(['age','salary'], axis=1)
target_df
# Out:
#        age  salary
# 0       39   <=50K
# 1       50   <=50K
# 2       38   <=50K
# 3       53   <=50K
# 4       28   <=50K
# ...    ...     ...
# 32556   27   <=50K
# 32557   40    >50K
# 32558   58   <=50K
# 32559   22   <=50K
# 32560   52    >50K
#
# [32561 rows x 2 columns]

# %%
#import sqlite3

# %%
#sqlite3.connect('salary.db')
#conn = sqlite3.connect('salary.db')
#c = conn.cursor()

# %%
#project_df.to_sql(name ='salary', con=conn, if_exists='replace', index=False)
#conn.commit
