# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
#import tensorflow as tf

# %%
project_df = pd.read_csv("resources/salary.csv")
project_df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  salary
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %%
project_df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# salary            object
# dtype: object

# %%
project_df.sample(20)
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 18045   23            Private  211601   Some-college             10
# 10799   45          Local-gov  215862      Doctorate             16
# 212     35            Private  153790   Some-college             10
# 10821   23            Private  176486   Some-college             10
# 9078    23            Private  433669     Assoc-acdm             12
# 22314   25          Local-gov  190107        HS-grad              9
# 31121   35            Private  159179   Some-college             10
# 8411    43            Private  313181        HS-grad              9
# 23031   32            Private   32406      Bachelors             13
# 9771    24            Private  168997   Some-college             10
# 30094   65            Private   88513        HS-grad              9
# 12289   40   Self-emp-not-inc   48859        HS-grad              9
# 10096   42   Self-emp-not-inc  308279      Bachelors             13
# 20861   55   Self-emp-not-inc  126117        HS-grad              9
# 4388    29            Private   37215        HS-grad              9
# 13257   49            Private   50474        HS-grad              9
# 27425   41          State-gov   29324        HS-grad              9
# 11238   84       Self-emp-inc  172907   Some-college             10
# 906     37            Private  211154   Some-college             10
# 31239   51            Private   99987           10th              6
#
#             marital-status          occupation     relationship  \
# 18045   Married-civ-spouse     Exec-managerial             Wife
# 10799   Married-civ-spouse     Exec-managerial          Husband
# 212          Never-married               Sales    Not-in-family
# 10821        Never-married       Other-service   Other-relative
# 9078         Never-married        Adm-clerical    Not-in-family
# 22314        Never-married     Farming-fishing        Own-child
# 31121        Never-married               Sales    Not-in-family
# 8411              Divorced        Adm-clerical   Other-relative
# 23031        Never-married      Prof-specialty    Not-in-family
# 9771    Married-civ-spouse        Craft-repair          Husband
# 30094   Married-civ-spouse               Sales          Husband
# 12289   Married-civ-spouse        Craft-repair          Husband
# 10096   Married-civ-spouse      Prof-specialty          Husband
# 20861              Widowed               Sales    Not-in-family
# 4388    Married-civ-spouse        Craft-repair          Husband
# 13257   Married-civ-spouse     Exec-managerial          Husband
# 27425             Divorced     Exec-managerial        Unmarried
# 11238   Married-civ-spouse               Sales          Husband
# 906               Divorced   Machine-op-inspct    Not-in-family
# 31239            Separated   Machine-op-inspct        Unmarried
#
#                       race      sex  capital-gain  capital-loss  \
# 18045                Black   Female             0             0
# 10799                White     Male          7688             0
# 212     Amer-Indian-Eskimo   Female             0             0
# 10821                White   Female             0             0
# 9078                 White     Male             0             0
# 22314                White     Male             0          1719
# 31121                White     Male             0             0
# 8411                 Black     Male             0             0
# 23031                White   Female             0             0
# 9771                 White     Male             0             0
# 30094                White     Male             0             0
# 12289                White     Male             0             0
# 10096                White     Male             0             0
# 20861                White     Male             0             0
# 4388                 White     Male             0             0
# 13257                White     Male             0             0
# 27425                White   Female             0             0
# 11238                White     Male             0             0
# 906                  White     Male             0             0
# 31239                Black   Female             0             0
#
#        hours-per-week  native-country  salary
# 18045              40   United-States   <=50K
# 10799              45   United-States    >50K
# 212                40   United-States   <=50K
# 10821              25   United-States   <=50K
# 9078               40   United-States   <=50K
# 22314              16   United-States   <=50K
# 31121              40   United-States   <=50K
# 8411               38   United-States   <=50K
# 23031              50   United-States   <=50K
# 9771               40   United-States   <=50K
# 30094              18   United-States   <=50K
# 12289              32   United-States   <=50K
# 10096              21   United-States   <=50K
# 20861              40   United-States   <=50K
# 4388               55   United-States   <=50K
# 13257              40   United-States   <=50K
# 27425              45   United-States   <=50K
# 11238              35   United-States    >50K
# 906                52   United-States   <=50K
# 31239              40   United-States   <=50K

# %%
project_df.nunique()
# Out:
# age                  73
# workclass             9
# fnlwgt            21648
# education            16
# education-num        16
# marital-status        7
# occupation           15
# relationship          6
# race                  5
# sex                   2
# capital-gain        119
# capital-loss         92
# hours-per-week       94
# native-country       42
# salary                2
# dtype: int64

# %%
## Create Features DataFrame
features_df = project_df.filter(['age', 'workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex','hours-per-week', 'native-country' ], axis = 1)
features_df
# Out:
#        age          workclass    education       marital-status  \
# 0       39          State-gov    Bachelors        Never-married
# 1       50   Self-emp-not-inc    Bachelors   Married-civ-spouse
# 2       38            Private      HS-grad             Divorced
# 3       53            Private         11th   Married-civ-spouse
# 4       28            Private    Bachelors   Married-civ-spouse
# ...    ...                ...          ...                  ...
# 32556   27            Private   Assoc-acdm   Married-civ-spouse
# 32557   40            Private      HS-grad   Married-civ-spouse
# 32558   58            Private      HS-grad              Widowed
# 32559   22            Private      HS-grad        Never-married
# 32560   52       Self-emp-inc      HS-grad   Married-civ-spouse
#
#                occupation    relationship    race      sex  hours-per-week  \
# 0            Adm-clerical   Not-in-family   White     Male              40
# 1         Exec-managerial         Husband   White     Male              13
# 2       Handlers-cleaners   Not-in-family   White     Male              40
# 3       Handlers-cleaners         Husband   Black     Male              40
# 4          Prof-specialty            Wife   Black   Female              40
# ...                   ...             ...     ...      ...             ...
# 32556        Tech-support            Wife   White   Female              38
# 32557   Machine-op-inspct         Husband   White     Male              40
# 32558        Adm-clerical       Unmarried   White   Female              40
# 32559        Adm-clerical       Own-child   White     Male              20
# 32560     Exec-managerial            Wife   White   Female              40
#
#        native-country
# 0       United-States
# 1       United-States
# 2       United-States
# 3       United-States
# 4                Cuba
# ...               ...
# 32556   United-States
# 32557   United-States
# 32558   United-States
# 32559   United-States
# 32560   United-States
#
# [32561 rows x 10 columns]

# %%
#create target df
target_df = project_df.filter(['age','salary'], axis=1)
target_df
# Out:
#        age  salary
# 0       39   <=50K
# 1       50   <=50K
# 2       38   <=50K
# 3       53   <=50K
# 4       28   <=50K
# ...    ...     ...
# 32556   27   <=50K
# 32557   40    >50K
# 32558   58   <=50K
# 32559   22   <=50K
# 32560   52    >50K
#
# [32561 rows x 2 columns]

# %%
# Renaming titles columns
features_df = features_df.rename(columns={'workclass':'work_class','marital-status': 'martial_status','hours-per-week':'hours_per_week','native-country':'native_country'})
features_df
# Out:
#        age         work_class    education       martial_status  \
# 0       39          State-gov    Bachelors        Never-married
# 1       50   Self-emp-not-inc    Bachelors   Married-civ-spouse
# 2       38            Private      HS-grad             Divorced
# 3       53            Private         11th   Married-civ-spouse
# 4       28            Private    Bachelors   Married-civ-spouse
# ...    ...                ...          ...                  ...
# 32556   27            Private   Assoc-acdm   Married-civ-spouse
# 32557   40            Private      HS-grad   Married-civ-spouse
# 32558   58            Private      HS-grad              Widowed
# 32559   22            Private      HS-grad        Never-married
# 32560   52       Self-emp-inc      HS-grad   Married-civ-spouse
#
#                occupation    relationship    race      sex  hours_per_week  \
# 0            Adm-clerical   Not-in-family   White     Male              40
# 1         Exec-managerial         Husband   White     Male              13
# 2       Handlers-cleaners   Not-in-family   White     Male              40
# 3       Handlers-cleaners         Husband   Black     Male              40
# 4          Prof-specialty            Wife   Black   Female              40
# ...                   ...             ...     ...      ...             ...
# 32556        Tech-support            Wife   White   Female              38
# 32557   Machine-op-inspct         Husband   White     Male              40
# 32558        Adm-clerical       Unmarried   White   Female              40
# 32559        Adm-clerical       Own-child   White     Male              20
# 32560     Exec-managerial            Wife   White   Female              40
#
#        native_country
# 0       United-States
# 1       United-States
# 2       United-States
# 3       United-States
# 4                Cuba
# ...               ...
# 32556   United-States
# 32557   United-States
# 32558   United-States
# 32559   United-States
# 32560   United-States
#
# [32561 rows x 10 columns]

# %%
# Add this import for sql database
import sqlite3

# %%
# connecting to 'features.db'
conn = sqlite3.connect('features.db')

# %%
# Adding feature_df database
features_df.to_sql(name ='features', con=conn, if_exists='replace', index=False)
conn.commit
# Out:
# <function Connection.commit>

# %%
# connecting to 'target.db'
conn = sqlite3.connect('target.db')

# %%
# Adding target_df to database
target_df.to_sql(name ='target', con=conn, if_exists='replace', index=False)
conn.commit
# Out:
# <function Connection.commit>
